# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

# %%
embedded_path = "E:\\xianglin\\git_space\\umap_exp\\results\\umap\\cifar10_200\\train_embedding.npy"
content_path = "E:\\DVI_exp_data\\resnet18_cifar10\\Training_data\\training_dataset_label.pth"

# %%
train_embedding = np.load(embedded_path)
label = torch.load(content_path).cpu().numpy()

# %%
train_embedding.shape, label.shape
# Out:
# ((50000, 2), (50000,))

# %%
colors = plt.get_cmap("tab10")
colors = [colors(int(label[i])) for i in range(len(label))]

# %%
plt.scatter(train_embedding[:, 0], train_embedding[:, 1], s=0.1, c=colors, alpha=0.5)
plt.savefig("vis.png")
